# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.2'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
display(df)
num_rows, num_cols = df.shape
print("# of cols : ", num_cols)
print("# of rowa : ", num_rows)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
#data 1 - n (diurutkan berdasarkan ascending)
df.head(5)
#data n - 1 (diurutkan berdasarkan descending)
df.tail(10)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126305      63153  201506070GSW   NBA        0     2015   6/7/2015
# 126306      63154  201506090CLE   NBA        1     2015   6/9/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126308      63155  201506110CLE   NBA        1     2015  6/11/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126304          98            1     CLE  Cavaliers  ...  61.312763     GSW
# 126305          99            1     GSW   Warriors  ...  67.029549     CLE
# ...

# %%
df_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patient_id      893 non-null    int64
#  1   gender          156 non-null    object
#  2   age             156 non-null    float64
#  3   nationality     156 non-null    object
#  4   province        156 non-null    object
#  5   current_state   166 non-null    object
#  6   contacted_with  27 non-null     float64
#  7   confirmed_date  893 non-null    object
#  8   released_date   5 non-null      object
#  9   deceased_date   4 non-null      object
#  10  hospital        17 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 76.9+ KB

# %%
df_corona = pd.read_csv("csv/patient.csv")
display(df_corona)
# Out:
#      patient_id  gender   age nationality     province current_state  \
# 0             1  female  31.0   indonesia  DKI Jakarta      released
# 1             2  female  64.0   indonesia  DKI Jakarta      released
# 2             3  female  33.0   indonesia  DKI Jakarta      released
# 3             4  female  34.0   indonesia  DKI Jakarta      isolated
# 4             5    male  55.0   indonesia  DKI Jakarta      isolated
# ..          ...     ...   ...         ...          ...           ...
# 888         889     NaN   NaN         NaN          NaN           NaN
# 889         890     NaN   NaN         NaN          NaN           NaN
# 890         891     NaN   NaN         NaN          NaN           NaN
# 891         892     NaN   NaN         NaN          NaN           NaN
# 892         893     NaN   NaN         NaN          NaN           NaN
#
#      contacted_with confirmed_date released_date deceased_date  \
# 0               NaN       2-Mar-20     13-Mar-20           NaN
# ...

# %%
df_corona.head(10)
# Out:
#    patient_id  gender   age nationality     province current_state  \
# 0           1  female  31.0   indonesia  DKI Jakarta      released
# 1           2  female  64.0   indonesia  DKI Jakarta      released
# 2           3  female  33.0   indonesia  DKI Jakarta      released
# 3           4  female  34.0   indonesia  DKI Jakarta      isolated
# 4           5    male  55.0   indonesia  DKI Jakarta      isolated
# 5           6    male  36.0   indonesia  DKI Jakarta      released
# 6           7  female  54.0   indonesia  DKI Jakarta      released
# 7           8    male  55.0   indonesia  DKI Jakarta      released
# 8           9  female  55.0   indonesia  DKI Jakarta      released
# 9          10    male  29.0   foreigner  DKI Jakarta      isolated
#
#    contacted_with confirmed_date released_date deceased_date  \
# 0             NaN       2-Mar-20     13-Mar-20           NaN
# 1             1.0       2-Mar-20     16-Mar-20           NaN
# ...

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
with pd.option_context("display.max.columns", None, "display.precision", 2):
    display(df)
    display(df_corona.describe())
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
display(df_corona.describe(include="object"))
# Out:
#        gender nationality     province current_state confirmed_date  \
# count     156         156          156           166            893
# unique      2           2           10             3             20
# top      male   indonesia  DKI Jakarta      isolated      24-Mar-20
# freq       91         147          124           143            106
#
#        released_date deceased_date              hospital
# count              5             4                    17
# unique             3             2                     4
# top        11-Mar-20     11-Mar-20  RSPI Sulianti Saroso
# freq               2             2                     8

# %%
df_corona["current_state"].value_counts()
df_corona["current_state"].unique()
# Out:
# array(['released', 'isolated', 'deceased', nan], dtype=object)

# %%
df_corona[["gender", "hospital"]].value_counts()
# Out:
# gender  hospital
# female  RSPI Sulianti Saroso    7
# male    RS Persahabatan         6
#         RSPI Sulianti Saroso    1
#         RS Dr Moewardi          1
# female  RS Sanglah              1
#         RS Persahabatan         1
# dtype: int64

# %%
df_corona.loc[:, ["hospital"]]
# Out:
#                  hospital
# 0    RSPI Sulianti Saroso
# 1    RSPI Sulianti Saroso
# 2    RSPI Sulianti Saroso
# 3    RSPI Sulianti Saroso
# 4         RS Persahabatan
# ..                    ...
# 888                   NaN
# 889                   NaN
# 890                   NaN
# 891                   NaN
# 892                   NaN
#
# [893 rows x 1 columns]

# %%
df_corona.loc[df_corona["hospital"]=="RSPI Sulianti Saroso", ["patient_id", "gender", "hospital"]].min()
# Out:
# patient_id                       1
# gender                      female
# hospital      RSPI Sulianti Saroso
# dtype: object

# %%
city_revenues=pd.Series(
    [1, 2, 3, 4],
    index=["A", "B", "C", "D"]
)
print(city_revenues, city_revenues.index)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64 Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
dict_series = pd.Series(
    {
        "companyID" : 10,
        "companyName": "PT Sehat Sejahtera",
        "companyPhone": 8112234517,
    }
)
print(dict_series)
# Out:
# companyID                       10
# companyName     PT Sehat Sejahtera
# companyPhone            8112234517
# dtype: object

# %%
dict_data_frame = pd.DataFrame(
    {
        "Keys": city_revenues,
        "Value": dict_series
    }
)
dict_data_frame
# Out:
#               Keys               Value
# A              1.0                 NaN
# B              2.0                 NaN
# C              3.0                 NaN
# D              4.0                 NaN
# companyID      NaN                  10
# companyName    NaN  PT Sehat Sejahtera
# companyPhone   NaN          8112234517

# %%
dict_data_frame.columns
# Out:
# Index(['Keys', 'Value'], dtype='object')

# %%
df_corona.iloc[:2, [2, 3]]
# Out:
#     age nationality
# 0  31.0   indonesia
# 1  64.0   indonesia

# %%
df_corona.loc[0]
# Out:
# patient_id                           1
# gender                          female
# age                                 31
# nationality                  indonesia
# province                   DKI Jakarta
# current_state                 released
# contacted_with                     NaN
# confirmed_date                2-Mar-20
# released_date                13-Mar-20
# deceased_date                      NaN
# hospital          RSPI Sulianti Saroso
# Name: 0, dtype: object

# %%
df_nba = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
df_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  opp_id  opp_fran  opp_pts  opp_elo_i  \
# 0            0     TRH  Huskies  ...     NYK    Knicks       68  1300.0000
# 1            0     NYK   Knicks  ...     TRH   Huskies       66  1300.0000
# 2            0     CHS    Stags  ...     NYK    Knicks       47  1306.7233
# 3            0     NYK   Knicks  ...     CHS     Stags       63  1300.0000
# 4            0     DTF  Falcons  ...     WSC  Capitols       50  1300.0000
#
#    opp_elo_n game_location  game_result  forecast  notes  year
# ...

# %%
df_nba["year"] = '2020'

# %%
df_nba["diffrence"] = df_nba["pts"] - df_nba["opp_pts"]

# %%
df_nba[["pts", "opp_pts", "diffrence"]].head()
# Out:
#    pts  opp_pts  diffrence
# 0   66       68         -2
# 1   68       66          2
# 2   63       47         16
# 3   47       63        -16
# 4   33       50        -17

# %%
rnm_df_nba = df_nba.rename(
    columns={
        "pts": "point"
    }
)
rnm_df_nba[["point"]].head()
# Out:
#    point
# 0     66
# 1     68
# 2     63
# 3     47
# 4     33

# %%
df_nba[
    (df_nba["fran_id"] == "Warriors")
    & (df_nba["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64
